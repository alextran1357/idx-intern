# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
save_path = Path("../../data/combined")

# %%
sold = pd.read_csv(save_path/"sold.csv")
# Out:
# C:\Users\alext\AppData\Local\Temp\ipykernel_25884\2557060698.py:1: DtypeWarning: Columns (0: BuyerAgentAOR, 1: ListAgentAOR, 2: ListAgentEmail, 3: FireplaceYN, 4: OriginatingSystemName, 5: OriginatingSystemSubName, 6: BuyerAgencyCompensationType, 7: latfilled, 8: lonfilled) have mixed types. Specify dtype option on import or set low_memory=False.
#   sold = pd.read_csv(save_path/"sold.csv")

# %%
sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'OriginatingSystemName', 'OriginatingSystemSubName',
#        'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'latfilled',
#        'lonfilled'],
#       dtype='str')

# %%
# Identify number of rows/columns
sold.shape
# Out:
# (397540, 84)

# %%
pd.options.display.max_rows = 100

# %%
listing = pd.read_csv(save_path/"listing.csv")

sold_columns = []
listing_columns = []
for c in sold.columns:
    sold_columns.append(c)
for c in listing.columns:
    listing_columns.append(c)

print(list(set(sold_columns)-set(listing_columns)))
print(list(set(listing_columns)-set(sold_columns)))
# Out:
# C:\Users\alext\AppData\Local\Temp\ipykernel_25884\529776706.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: ElementarySchool, 2: BuyerAgencyCompensationType, 3: MiddleOrJuniorSchool, 4: FireplaceYN) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing = pd.read_csv(save_path/"listing.csv")
# ['BasementYN', 'OriginatingSystemSubName', 'lonfilled', 'Flooring', 'WaterfrontYN', 'ViewYN', 'PoolPrivateYN', 'ListAgentAOR', 'OriginatingSystemName', 'latfilled', 'BuyerAgentAOR']
# ['BuyerOfficeName.1', 'UnparsedAddress.1', 'CloseDate.1', 'PropertyType.1', 'Longitude.1', 'DaysOnMarket.1', 'Latitude.1', 'ListAgentFirstName.1', 'ListAgentLastName.1', 'LivingArea.1', 'ListPrice.1']

# %%
sold[['BasementYN', 'OriginatingSystemSubName', 'lonfilled', 'Flooring', 'WaterfrontYN', 'ViewYN', 'PoolPrivateYN', 'ListAgentAOR', 'OriginatingSystemName', 'latfilled', 'BuyerAgentAOR']].dtypes
# Out:
# BasementYN                  object
# OriginatingSystemSubName       str
# lonfilled                   object
# Flooring                       str
# WaterfrontYN                object
# ViewYN                      object
# PoolPrivateYN               object
# ListAgentAOR                   str
# OriginatingSystemName          str
# latfilled                   object
# BuyerAgentAOR                  str
# dtype: object

# %%
# Review column data types
sold.dtypes
# Out:
# BuyerAgentAOR                       str
# ListAgentAOR                        str
# Flooring                            str
# ViewYN                           object
# WaterfrontYN                     object
# BasementYN                       object
# PoolPrivateYN                    object
# OriginalListPrice               float64
# ListingKey                        int64
# ListAgentEmail                      str
# CloseDate                           str
# ClosePrice                      float64
# ListAgentFirstName                  str
# ListAgentLastName                   str
# Latitude                        float64
# Longitude                       float64
# UnparsedAddress                     str
# PropertyType                        str
# LivingArea                      float64
# ListPrice                       float64
# DaysOnMarket                      int64
# ListOfficeName                      str
# BuyerOfficeName                     str
# CoListOfficeName                    str
# ListAgentFullName                   str
# CoListAgentFirstName                str
# CoListAgentLastName                 str
# BuyerAgentMlsId                     str
# BuyerAgentFirstName                 str
# BuyerAgentLastName                  str
# FireplacesTotal                 float64
# AssociationFeeFrequency             str
# AboveGradeFinishedArea          float64
# ListingKeyNumeric                 int64
# MLSAreaMajor                        str
# TaxAnnualAmount                 float64
# CountyOrParish                      str
# MlsStatus                           str
# ElementarySchool                    str
# AttachedGarageYN                 object
# ParkingTotal                    float64
# BuilderName                         str
# PropertySubType                     str
# LotSizeAcres                    float64
# SubdivisionName                     str
# BuyerOfficeAOR                      str
# YearBuilt                       float64
# StreetNumberNumeric             float64
# ListingId                           str
# BathroomsTotalInteger           float64
# City                                str
# TaxYear                         float64
# BuildingAreaTotal               float64
# BedroomsTotal                   float64
# ContractStatusChangeDate            str
# ElementarySchoolDistrict        float64
# CoBuyerAgentFirstName               str
# PurchaseContractDate                str
# ListingContractDate                 str
# BelowGradeFinishedArea          float64
# BusinessType                    float64
# StateOrProvince                     str
# CoveredSpaces                   float64
# MiddleOrJuniorSchool                str
# FireplaceYN                      object
# Stories                         float64
# HighSchool                          str
# Levels                              str
# LotSizeDimensions                   str
# LotSizeArea                     float64
# MainLevelBedrooms               float64
# NewConstructionYN                object
# GarageSpaces                    float64
# HighSchoolDistrict                  str
# PostalCode                          str
# AssociationFee                  float64
# LotSizeSquareFeet               float64
# MiddleOrJuniorSchoolDistrict    float64
# OriginatingSystemName               str
# OriginatingSystemSubName            str
# BuyerAgencyCompensationType         str
# BuyerAgencyCompensation         float64
# latfilled                        object
# lonfilled                        object
# dtype: object

# %% [markdown]
# ## Dtypes changes
# * BasementYN (Bool)
# * WaterfrontYN (Bool)
# * ViewYN (Bool)
# * PoolPrivateYN (Bool)
# *
# * OriginalListPrice (int)
# * CloseDate (DateTime)
# * FireplacesTotal (int)
# * AttachedGarageYN (bool)
# * YearBuilt (int)
# * StreetNumberNumeric (int)
# * BathroomsTotalInteger (int)
# * TaxYear (int)
# * BedroomsTotal (int)
# * ContractStatusChangeDate (DateTime)
# * ElementarySchoolDistrict (string)
# * PurchaseContractDate (DateTime)
# * ListingContractDate (DateTime)
# * BusinessType
# * FireplaceYN (Bool)
# * Stories (Int)
# * MainLevelBedrooms (Int)
# * NewConstructionYN (Bool)

# %%
# Identify High-missing columns
# Calculate missing counts and percentages per column
# percent missing data per column
missing_count = sold.isnull().sum()
percent_missing = round(missing_count * 100 / len(sold), 2)
missing_value_df = pd.DataFrame(
    {
        'missing_count': missing_count,
        'percent_missing': percent_missing
    }
)
missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df
# Out:
#                               missing_count  percent_missing
# CloseDate                                 0             0.00
# ClosePrice                                2             0.00
# ListingKey                                0             0.00
# PropertyType                              0             0.00
# DaysOnMarket                              0             0.00
# ListOfficeName                            0             0.00
# ListPrice                                 0             0.00
# ListingKeyNumeric                         0             0.00
# ListingId                                 0             0.00
# BedroomsTotal                            11             0.00
# StateOrProvince                           0             0.00
# ListingContractDate                       1             0.00
# CountyOrParish                            0             0.00
# MlsStatus                                 0             0.00
# PostalCode                                2             0.00
# ListAgentLastName                        40             0.01
# BathroomsTotalInteger                    69             0.02
# ListAgentFullName                        85             0.02
# BuyerAgentLastName                      169             0.04
# PurchaseContractDate                    194             0.05
# LivingArea                              229             0.06
# City                                    310             0.08
# FireplaceYN                             316             0.08
# YearBuilt                               356             0.09
# UnparsedAddress                         362             0.09
# ParkingTotal                            426             0.11
# StreetNumberNumeric                     445             0.11
# BuyerAgentMlsId                         505             0.13
# ContractStatusChangeDate                589             0.15
# OriginalListPrice                       719             0.18
# PropertySubType                         776             0.20
# BuyerAgentFirstName                    1955             0.49
# ListAgentFirstName                     2999             0.75
# BuyerOfficeName                        6539             1.64
# Latitude                              15816             3.98
# Longitude                             15816             3.98
# GarageSpaces                          17040             4.29
# BuyerOfficeAOR                        21440             5.39
# ListAgentEmail                        28949             7.28
# NewConstructionYN                     29442             7.41
# LotSizeArea                           30846             7.76
# LotSizeSquareFeet                     30970             7.79
# LotSizeAcres                          31347             7.89
# ViewYN                                33859             8.52
# PoolPrivateYN                         34429             8.66
# Levels                                38566             9.70
# ListAgentAOR                          46186            11.62
# BuyerAgentAOR                         49083            12.35
# MLSAreaMajor                          53109            13.36
# AttachedGarageYN                      60659            15.26
# Stories                               61493            15.47
# AssociationFee                        90969            22.88
# HighSchoolDistrict                   108809            27.37
# Flooring                             142562            35.86
# MainLevelBedrooms                    166783            41.95
# AssociationFeeFrequency              232019            58.36
# SubdivisionName                      249841            62.85
# CoListOfficeName                     303479            76.34
# CoListAgentLastName                  306334            77.06
# CoListAgentFirstName                 306569            77.12
# HighSchool                           328291            82.58
# latfilled                            333656            83.93
# lonfilled                            333656            83.93
# MiddleOrJuniorSchool                 344211            86.59
# ElementarySchool                     344564            86.67
# BuyerAgencyCompensationType          351404            88.39
# BuyerAgencyCompensation              351415            88.40
# OriginatingSystemName                358351            90.14
# OriginatingSystemSubName             358351            90.14
# CoBuyerAgentFirstName                361527            90.94
# BuildingAreaTotal                    369763            93.01
# BuilderName                          377998            95.08
# LotSizeDimensions                    378228            95.14
# BasementYN                           389764            98.04
# BelowGradeFinishedArea               395250            99.42
# WaterfrontYN                         397292            99.94
# AboveGradeFinishedArea               397540           100.00
# TaxAnnualAmount                      397540           100.00
# FireplacesTotal                      397540           100.00
# ElementarySchoolDistrict             397540           100.00
# CoveredSpaces                        397540           100.00
# BusinessType                         397540           100.00
# TaxYear                              397540           100.00
# MiddleOrJuniorSchoolDistrict         397540           100.00

# %%
sold.describe().T
# Out:
#                                  count          mean           std  \
# OriginalListPrice             396821.0  1.224704e+06  6.780298e+06
# ListingKey                    397540.0  1.095900e+09  2.992964e+07
# ClosePrice                    397538.0  1.187275e+06  6.015489e+06
# Latitude                      381724.0  3.465276e+01  1.707091e+00
# Longitude                     381724.0 -1.185693e+02  2.956342e+00
# LivingArea                    397311.0  1.904329e+03  2.701995e+04
# ListPrice                     397540.0  1.138577e+06  1.353665e+06
# DaysOnMarket                  397540.0  3.733197e+01  5.353295e+01
# FireplacesTotal                    0.0           NaN           NaN
# AboveGradeFinishedArea             0.0           NaN           NaN
# ListingKeyNumeric             397540.0  1.095900e+09  2.992964e+07
# TaxAnnualAmount                    0.0           NaN           NaN
# ParkingTotal                  397114.0  9.325282e+00  4.115985e+03
# LotSizeAcres                  366193.0  6.856736e+01  1.632826e+04
# YearBuilt                     397184.0  1.978567e+03  2.627136e+01
# StreetNumberNumeric           397095.0  1.044228e+04  2.288204e+05
# BathroomsTotalInteger         397471.0  2.533123e+00  1.135940e+00
# TaxYear                            0.0           NaN           NaN
# BuildingAreaTotal              27777.0  2.118567e+03  1.704943e+03
# BedroomsTotal                 397529.0  3.200212e+00  1.067417e+00
# ElementarySchoolDistrict           0.0           NaN           NaN
# BelowGradeFinishedArea          2290.0  9.800053e+01  7.370422e+02
# BusinessType                       0.0           NaN           NaN
# CoveredSpaces                      0.0           NaN           NaN
# Stories                       336047.0  1.364294e+00  4.812324e-01
# LotSizeArea                   366694.0  3.839052e+04  2.139863e+06
# MainLevelBedrooms             230757.0  2.059066e+00  7.242000e+00
# GarageSpaces                  380500.0  1.858474e+00  3.706854e+00
# AssociationFee                306571.0  2.348124e+02  1.772388e+03
# LotSizeSquareFeet             366570.0  3.347472e+05  1.630774e+07
# MiddleOrJuniorSchoolDistrict       0.0           NaN           NaN
# BuyerAgencyCompensation        46125.0  2.219297e+02  2.590407e+03
#
#                                        min           25%           50%  \
# OriginalListPrice             0.000000e+00  5.850000e+05  8.250000e+05
# ListingKey                    4.216785e+08  1.075067e+09  1.093945e+09
# ClosePrice                    0.000000e+00  5.750000e+05  8.200000e+05
# Latitude                     -1.174725e+02  3.373655e+01  3.404679e+01
# Longitude                    -1.776467e+02 -1.188803e+02 -1.180144e+02
# LivingArea                    0.000000e+00  1.247000e+03  1.641000e+03
# ListPrice                     5.250000e+02  5.750000e+05  8.150000e+05
# DaysOnMarket                 -2.880000e+02  8.000000e+00  1.900000e+01
# FireplacesTotal                        NaN           NaN           NaN
# AboveGradeFinishedArea                 NaN           NaN           NaN
# ListingKeyNumeric             4.216785e+08  1.075067e+09  1.093945e+09
# TaxAnnualAmount                        NaN           NaN           NaN
# ParkingTotal                 -1.430000e+02  2.000000e+00  2.000000e+00
# LotSizeAcres                  0.000000e+00  1.200000e-01  1.663000e-01
# YearBuilt                     1.776000e+03  1.960000e+03  1.979000e+03
# StreetNumberNumeric           0.000000e+00  1.006000e+03  3.301000e+03
# BathroomsTotalInteger         0.000000e+00  2.000000e+00  2.000000e+00
# TaxYear                                NaN           NaN           NaN
# BuildingAreaTotal             0.000000e+00  1.270000e+03  1.714000e+03
# BedroomsTotal                 0.000000e+00  3.000000e+00  3.000000e+00
# ElementarySchoolDistrict               NaN           NaN           NaN
# BelowGradeFinishedArea        0.000000e+00  0.000000e+00  0.000000e+00
# BusinessType                           NaN           NaN           NaN
# CoveredSpaces                          NaN           NaN           NaN
# Stories                       1.000000e+00  1.000000e+00  1.000000e+00
# LotSizeArea                   0.000000e+00  5.000000e+03  7.016000e+03
# MainLevelBedrooms             0.000000e+00  1.000000e+00  2.000000e+00
# GarageSpaces                  0.000000e+00  2.000000e+00  2.000000e+00
# AssociationFee                0.000000e+00  0.000000e+00  9.500000e+01
# LotSizeSquareFeet             0.000000e+00  5.227000e+03  7.242000e+03
# MiddleOrJuniorSchoolDistrict           NaN           NaN           NaN
# BuyerAgencyCompensation       0.000000e+00  2.000000e+00  2.500000e+00
#
#                                        75%           max
# OriginalListPrice             1.299000e+06  1.390000e+09
# ListingKey                    1.115088e+09  1.156816e+09
# ClosePrice                    1.300000e+06  9.895000e+08
# Latitude                      3.455321e+01  5.613037e+01
# Longitude                    -1.172679e+02  3.290000e+02
# LivingArea                    2.217000e+03  1.702132e+07
# ListPrice                     1.295000e+06  1.375000e+08
# DaysOnMarket                  4.800000e+01  1.243000e+04
# FireplacesTotal                        NaN           NaN
# AboveGradeFinishedArea                 NaN           NaN
# ListingKeyNumeric             1.115088e+09  1.156816e+09
# TaxAnnualAmount                        NaN           NaN
# ParkingTotal                  3.000000e+00  2.593669e+06
# LotSizeAcres                  2.724000e-01  7.810698e+06
# YearBuilt                     1.999000e+03  2.026000e+03
# StreetNumberNumeric           1.203000e+04  7.814782e+07
# BathroomsTotalInteger         3.000000e+00  1.750000e+02
# TaxYear                                NaN           NaN
# BuildingAreaTotal             2.458000e+03  1.237640e+05
# BedroomsTotal                 4.000000e+00  4.500000e+01
# ElementarySchoolDistrict               NaN           NaN
# BelowGradeFinishedArea        0.000000e+00  1.453100e+04
# BusinessType                           NaN           NaN
# CoveredSpaces                          NaN           NaN
# Stories                       2.000000e+00  2.000000e+00
# LotSizeArea                   1.089000e+04  9.187423e+08
# MainLevelBedrooms             3.000000e+00  3.333000e+03
# GarageSpaces                  2.000000e+00  6.000000e+02
# AssociationFee                3.686950e+02  7.500000e+05
# LotSizeSquareFeet             1.182475e+04  2.208318e+09
# MiddleOrJuniorSchoolDistrict           NaN           NaN
# BuyerAgencyCompensation       2.500000e+00  1.000000e+05

# %%
# Review column data types
sold.columns
# Out:
# Index(['BuyerAgentAOR', 'ListAgentAOR', 'Flooring', 'ViewYN', 'WaterfrontYN',
#        'BasementYN', 'PoolPrivateYN', 'OriginalListPrice', 'ListingKey',
#        'ListAgentEmail', 'CloseDate', 'ClosePrice', 'ListAgentFirstName',
#        'ListAgentLastName', 'Latitude', 'Longitude', 'UnparsedAddress',
#        'PropertyType', 'LivingArea', 'ListPrice', 'DaysOnMarket',
#        'ListOfficeName', 'BuyerOfficeName', 'CoListOfficeName',
#        'ListAgentFullName', 'CoListAgentFirstName', 'CoListAgentLastName',
#        'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName',
#        'FireplacesTotal', 'AssociationFeeFrequency', 'AboveGradeFinishedArea',
#        'ListingKeyNumeric', 'MLSAreaMajor', 'TaxAnnualAmount',
#        'CountyOrParish', 'MlsStatus', 'ElementarySchool', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'StreetNumberNumeric',
#        'ListingId', 'BathroomsTotalInteger', 'City', 'TaxYear',
#        'BuildingAreaTotal', 'BedroomsTotal', 'ContractStatusChangeDate',
#        'ElementarySchoolDistrict', 'CoBuyerAgentFirstName',
#        'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea',
#        'BusinessType', 'StateOrProvince', 'CoveredSpaces',
#        'MiddleOrJuniorSchool', 'FireplaceYN', 'Stories', 'HighSchool',
#        'Levels', 'LotSizeDimensions', 'LotSizeArea', 'MainLevelBedrooms',
#        'NewConstructionYN', 'GarageSpaces', 'HighSchoolDistrict', 'PostalCode',
#        'AssociationFee', 'LotSizeSquareFeet', 'MiddleOrJuniorSchoolDistrict',
#        'OriginatingSystemName', 'OriginatingSystemSubName',
#        'BuyerAgencyCompensationType', 'BuyerAgencyCompensation', 'latfilled',
#        'lonfilled'],
#       dtype='str')

# %% [markdown]
# # Market Analysis Fields FIX
# * OriginalListPrice
# * CloseDate
# * ClosePrice
# * Latitude
# * Longitude
# * PropertyType
# * LivingArea
# * ListPrice
# * DaysOnMarket
# * FireplacesTotal
# * AssociationFeeFrequency
# * AboveGradeFinishedArea
# * TaxAnnualAmount
# * CountyOrParish
# * ElementarySchool
# * AttachedGarageYN
# * ParkingTotal
# * PropertySubType
# * LotSizeAcres
# * YearBuilt
# * BathroomsTotalInteger
# * City
# * BuildingAreaTotal
# * BedroomsTotal
# * BelowGradeFinishedArea
# * StateOrProvince
# * CoveredSpaces
# * FireplaceYN
# * Stories
# * HighSchool
# * Levels
# * LotSizeDimensions
# * LotSizeArea
# * MainLevelBedrooms
# * NewConstructionYN
# * GarageSpaces
# * PostalCode
# * AssociationFee
# * LotSizeSquareFeet
# * MiddleOrJuniorSchoolDistrict
# * BasementYN
# * Flooring
# * WaterfrontYN
# * ViewYN
# * PoolPrivateYN

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['ClosePrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('ClosePrice Histogram (log scale)')

ax[1] = sold['ClosePrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('ClosePrice Boxplot')

plt.tight_layout()
plt.show()
sold['ClosePrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    3.975380e+05
# mean     1.187275e+06
# std      6.015489e+06
# min      0.000000e+00
# 25%      5.750000e+05
# 50%      8.200000e+05
# 75%      1.300000e+06
# 90%      2.058219e+06
# 95%      2.850000e+06
# 99%      5.550000e+06
# max      9.895000e+08
# Name: ClosePrice, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['ListPrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('ListPrice Histogram (log scale)')

ax[1] = sold['ListPrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('ListPrice Boxplot')

plt.tight_layout()
plt.show()
sold['ListPrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    3.975400e+05
# mean     1.138577e+06
# std      1.353665e+06
# min      5.250000e+02
# 25%      5.750000e+05
# 50%      8.150000e+05
# 75%      1.295000e+06
# 90%      1.999000e+06
# 95%      2.850000e+06
# 99%      5.695000e+06
# max      1.375000e+08
# Name: ListPrice, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['OriginalListPrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('OriginalListPrice Histogram (log scale)')

ax[1] = sold['OriginalListPrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('OriginalListPrice Boxplot')

plt.tight_layout()
plt.show()
sold['OriginalListPrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    3.968210e+05
# mean     1.224704e+06
# std      6.780298e+06
# min      0.000000e+00
# 25%      5.850000e+05
# 50%      8.250000e+05
# 75%      1.299000e+06
# 90%      2.050000e+06
# 95%      2.899000e+06
# 99%      5.995000e+06
# max      1.390000e+09
# Name: OriginalListPrice, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['LivingArea'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('LivingArea Histogram (log scale)')

ax[1] = sold['LivingArea'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('LivingArea Boxplot')

plt.tight_layout()
plt.show()
sold['LivingArea'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    3.973110e+05
# mean     1.904329e+03
# std      2.701995e+04
# min      0.000000e+00
# 25%      1.247000e+03
# 50%      1.641000e+03
# 75%      2.217000e+03
# 90%      2.975000e+03
# 95%      3.557500e+03
# 99%      5.280000e+03
# max      1.702132e+07
# Name: LivingArea, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['LotSizeAcres'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('LotSizeAcres Histogram (log scale)')

ax[1] = sold['LotSizeAcres'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('LotSizeAcres Boxplot')

plt.tight_layout()
plt.show()
sold['LotSizeAcres'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    3.661930e+05
# mean     6.856736e+01
# std      1.632826e+04
# min      0.000000e+00
# 25%      1.200000e-01
# 50%      1.663000e-01
# 75%      2.724000e-01
# 90%      1.040000e+00
# 95%      2.809820e+00
# 99%      1.080000e+01
# max      7.810698e+06
# Name: LotSizeAcres, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['BedroomsTotal'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('BedroomsTotal Histogram (log scale)')

ax[1] = sold['BedroomsTotal'].plot(kind="box", vert=False)
ax[1].set_title('BedroomsTotal Boxplot')

plt.tight_layout()
plt.show()
sold['BedroomsTotal'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    397529.000000
# mean          3.200212
# std           1.067417
# min           0.000000
# 25%           3.000000
# 50%           3.000000
# 75%           4.000000
# 90%           4.000000
# 95%           5.000000
# 99%           6.000000
# max          45.000000
# Name: BedroomsTotal, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['BathroomsTotalInteger'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('BathroomsTotalInteger Histogram (log scale)')

ax[1] = sold['BathroomsTotalInteger'].plot(kind="box", vert=False)
ax[1].set_title('BathroomsTotalInteger Boxplot')

plt.tight_layout()
plt.show()
sold['BathroomsTotalInteger'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    397471.000000
# mean          2.533123
# std           1.135940
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# 90%           4.000000
# 95%           4.000000
# 99%           6.000000
# max         175.000000
# Name: BathroomsTotalInteger, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['DaysOnMarket'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('DaysOnMarket Histogram (log scale)')

ax[1] = sold['DaysOnMarket'].plot(kind="box", vert=False)
ax[1].set_title('DaysOnMarket Boxplot')

plt.tight_layout()
plt.show()
sold['DaysOnMarket'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    397540.000000
# mean         37.331969
# std          53.532952
# min        -288.000000
# 25%           8.000000
# 50%          19.000000
# 75%          48.000000
# 90%          94.000000
# 95%         131.000000
# 99%         229.000000
# max       12430.000000
# Name: DaysOnMarket, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(sold['YearBuilt'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('YearBuilt Histogram (log scale)')

ax[1] = sold['YearBuilt'].plot(kind="box", vert=False)
ax[1].set_title('YearBuilt Boxplot')

plt.tight_layout()
plt.show()
sold['YearBuilt'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    397184.000000
# mean       1978.566901
# std          26.271360
# min        1776.000000
# 25%        1960.000000
# 50%        1979.000000
# 75%        1999.000000
# 90%        2016.000000
# 95%        2022.000000
# 99%        2025.000000
# max        2026.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# ## All of these follow the same structure of having the 99th percentile very large so it would be best if we removed them

# %% [markdown]
# # Reminder
# - Change specified dtpyes
# - Drop metadata columns
# - Drop 99th percentile
# - Drop missing columns
