# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
save_path = Path("../../data/combined")

# %%
listing = pd.read_csv(save_path/"listing.csv")
# Out:
# C:\Users\alext\AppData\Local\Temp\ipykernel_3040\1690057858.py:1: DtypeWarning: Columns (0: ListAgentEmail, 1: BuyerAgencyCompensationType) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing = pd.read_csv(save_path/"listing.csv")

# %%
listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
# ...

# %%
# Identify number of rows/columns
listing.shape
# Out:
# (566673, 84)

# %%
pd.options.display.max_rows = 100

# %%
listing[listing["CloseDate"].notna()]
# Out:
#         OriginalListPrice  ListingKey                ListAgentEmail  \
# 9               1249888.0  1073295259   sandra.mcfetridge@gmail.com
# 14               650000.0  1073219502               lorijo@tcsn.net
# 18              1025000.0  1073169832          doug@socalmodern.com
# 20               725000.0  1073164974      zachmickelson1@gmail.com
# 33               730000.0  1071104851     Antonio@AntonioMatier.com
# ...                   ...         ...                           ...
# 566639          2699000.0  1155337618           gina@ginacefalu.com
# 566641           649000.0  1155320481       angela@angelalotman.com
# 566646          2058000.0  1155258194        Shilpa.rao@compass.com
# 566650          1398500.0  1155207067        tony@machadorealty.com
# 566655           630000.0  1155141993  carla@freemanteam.properties
#
#          CloseDate  ClosePrice ListAgentFirstName  ListAgentLastName  \
# 9       2024-05-01   1262555.0             Sandra         McFetridge
# ...

# %%
# Review column data types
listing.dtypes
# Out:
# OriginalListPrice               float64
# ListingKey                        int64
# ListAgentEmail                      str
# CloseDate                           str
# ClosePrice                      float64
# ListAgentFirstName                  str
# ListAgentLastName                   str
# Latitude                        float64
# Longitude                       float64
# UnparsedAddress                     str
# PropertyType                        str
# LivingArea                      float64
# ListPrice                       float64
# DaysOnMarket                      int64
# ListOfficeName                      str
# BuyerOfficeName                     str
# CoListOfficeName                    str
# ListAgentFullName                   str
# CoListAgentFirstName                str
# CoListAgentLastName                 str
# BuyerAgentMlsId                     str
# BuyerAgentFirstName                 str
# BuyerAgentLastName                  str
# ...

# %% [markdown]
# ## Dtypes changes
# * CloseDate (DateTime)
# * FireplacesTotal (int)
# * AttachedGarageYN (bool)
# * YearBuilt (int)
# * StreetNumberNumeric (int)
# * BathroomsTotalInteger (int)
# * TaxYear (int)
# * BedroomsTotal (int)
# * ContractStatusChangeDate (DateTime)
# * ElementarySchoolDistrict (string)
# * PurchaseContractDate (DateTime)
# * ListingContractDate (DateTime)
# * BusinessType
# * FireplaceYN (Bool)
# * Stories (Int)
# * MainLevelBedrooms (Int)
# * NewConstructionYN (Bool)

# %%
# Identify High-missing columns
# Calculate missing counts and percentages per column
# percent missing data per column
missing_count = listing.isnull().sum()
percent_missing = round(missing_count * 100 / len(listing), 2)
missing_value_df = pd.DataFrame(
    {
        'missing_count': missing_count,
        'percent_missing': percent_missing
    }
)
missing_value_df.sort_values('percent_missing', inplace=True)
missing_value_df
# Out:
#                               missing_count  percent_missing
# ListingKey                                0             0.00
# DaysOnMarket                              0             0.00
# ListOfficeName                            0             0.00
# PropertyType                              0             0.00
# ListPrice                                 0             0.00
# MlsStatus                                 0             0.00
# PropertyType.1                            0             0.00
# CountyOrParish                            0             0.00
# ListingKeyNumeric                         0             0.00
# ListingId                                 0             0.00
# DaysOnMarket.1                            0             0.00
# ListingContractDate                       0             0.00
# ListPrice.1                               0             0.00
# ParkingTotal                             20             0.00
# ...

# %%
listing.describe().T
# Out:
#                                  count          mean           std  \
# OriginalListPrice             565861.0  1.399376e+06  7.279863e+06
# ListingKey                    566673.0  1.107276e+09  3.124776e+07
# ClosePrice                    146697.0  1.205656e+06  4.280644e+06
# Latitude                      486232.0  3.461414e+01  1.990551e+00
# Longitude                     486232.0 -1.184733e+02  3.560544e+00
# LivingArea                    566093.0  1.980580e+03  2.283133e+04
# ListPrice                     566673.0  1.316720e+06  2.411801e+06
# DaysOnMarket                  566673.0  1.910784e+01  2.631533e+01
# FireplacesTotal                    0.0           NaN           NaN
# AboveGradeFinishedArea             0.0           NaN           NaN
# ListingKeyNumeric             566673.0  1.107276e+09  3.124776e+07
# TaxAnnualAmount                    0.0           NaN           NaN
# ParkingTotal                  566653.0  7.399656e+00  3.445690e+03
# ...

# %%
# Review column data types
listing.columns
# Out:
# Index(['OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'CloseDate',
#        'ClosePrice', 'ListAgentFirstName', 'ListAgentLastName', 'Latitude',
#        'Longitude', 'UnparsedAddress', 'PropertyType', 'LivingArea',
#        'ListPrice', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName',
#        'CoListOfficeName', 'ListAgentFullName', 'CoListAgentFirstName',
#        'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'FireplacesTotal', 'AssociationFeeFrequency',
#        'AboveGradeFinishedArea', 'ListingKeyNumeric', 'MLSAreaMajor',
#        'TaxAnnualAmount', 'CountyOrParish', 'PropertyType.1', 'MlsStatus',
#        'ElementarySchool', 'ListAgentFirstName.1', 'AttachedGarageYN',
#        'ParkingTotal', 'BuilderName', 'PropertySubType', 'LotSizeAcres',
#        'SubdivisionName', 'BuyerOfficeAOR', 'YearBuilt', 'DaysOnMarket.1',
#        'BuyerAgencyCompensationType', 'StreetNumberNumeric', 'LivingArea.1',
# ...

# %% [markdown]
# # Market Analysis Fields
# * OriginalListPrice
# * CloseDate
# * ClosePrice
# * Latitude
# * Longitude
# * PropertyType
# * LivingArea
# * ListPrice
# * DaysOnMarket
# * FireplacesTotal
# * AssociationFeeFrequency
# * AboveGradeFinishedArea
# * TaxAnnualAmount
# * CountyOrParish
# * ElementarySchool
# * AttachedGarageYN
# * ParkingTotal
# * PropertySubType
# * LotSizeAcres
# * YearBuilt
# * BathroomsTotalInteger
# * City
# * BuildingAreaTotal
# * BedroomsTotal
# * BelowGradeFinishedArea
# * StateOrProvince
# * CoveredSpaces
# * FireplaceYN
# * Stories
# * HighSchool
# * Levels
# * LotSizeDimensions
# * LotSizeArea
# * MainLevelBedrooms
# * NewConstructionYN
# * GarageSpaces
# * PostalCode
# * AssociationFee
# * LotSizeSquareFeet
# * MiddleOrJuniorSchoolDistrict

# %% [markdown]
# ## ClosePrice

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['ClosePrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('ClosePrice Histogram (log scale)')

ax[1] = listing['ClosePrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('ClosePrice Boxplot')

plt.tight_layout()
plt.show()
listing['ClosePrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    1.466970e+05
# mean     1.205656e+06
# std      4.280644e+06
# min      5.250000e+02
# 25%      6.000000e+05
# 50%      8.550000e+05
# 75%      1.350000e+06
# 90%      2.150000e+06
# 95%      2.900000e+06
# 99%      5.500000e+06
# max      8.200000e+08
# Name: ClosePrice, dtype: float64

# %% [markdown]
# The boxplot shows a high number of outliers. Looking at the percentiles, 99% of the data is priced below 5.5m while the max is 820m.

# %% [markdown]
# ## ListingPrice

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['ListPrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('ListPrice Histogram (log scale)')

ax[1] = listing['ListPrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('ListPrice Boxplot')

plt.tight_layout()
plt.show()
listing['ListPrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    5.666730e+05
# mean     1.316720e+06
# std      2.411801e+06
# min      1.000000e+02
# 25%      5.800000e+05
# 50%      8.475000e+05
# 75%      1.380000e+06
# 90%      2.349940e+06
# 95%      3.450000e+06
# 99%      8.200000e+06
# max      4.000000e+08
# Name: ListPrice, dtype: float64

# %% [markdown]
# Same as ClosePrice.

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['OriginalListPrice'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('OriginalListPrice Histogram (log scale)')

ax[1] = listing['OriginalListPrice'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('OriginalListPrice Boxplot')

plt.tight_layout()
plt.show()
listing['OriginalListPrice'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    5.658610e+05
# mean     1.399376e+06
# std      7.279863e+06
# min      0.000000e+00
# 25%      5.850000e+05
# 50%      8.490000e+05
# 75%      1.395000e+06
# 90%      2.380000e+06
# 95%      3.495000e+06
# 99%      8.500000e+06
# max      1.390000e+09
# Name: OriginalListPrice, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['LivingArea'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('LivingArea Histogram (log scale)')

ax[1] = listing['LivingArea'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('LivingArea Boxplot')

plt.tight_layout()
plt.show()
listing['LivingArea'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    5.660930e+05
# mean     1.980580e+03
# std      2.283133e+04
# min      0.000000e+00
# 25%      1.248000e+03
# 50%      1.670000e+03
# 75%      2.301000e+03
# 90%      3.153000e+03
# 95%      3.871400e+03
# 99%      6.305000e+03
# max      1.702132e+07
# Name: LivingArea, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['LotSizeAcres'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('LotSizeAcres Histogram (log scale)')

ax[1] = listing['LotSizeAcres'].plot(kind="box", logx=True, vert=False)
ax[1].set_title('LotSizeAcres Boxplot')

plt.tight_layout()
plt.show()
listing['LotSizeAcres'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    5.200460e+05
# mean     6.297443e+01
# std      1.185040e+04
# min      0.000000e+00
# 25%      1.200000e-01
# 50%      1.700000e-01
# 75%      3.146000e-01
# 90%      1.350000e+00
# 95%      3.590000e+00
# 99%      1.349950e+01
# max      4.187292e+06
# Name: LotSizeAcres, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['BedroomsTotal'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('BedroomsTotal Histogram (log scale)')

ax[1] = listing['BedroomsTotal'].plot(kind="box", vert=False)
ax[1].set_title('BedroomsTotal Boxplot')

plt.tight_layout()
plt.show()
listing['BedroomsTotal'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    566519.000000
# mean          3.225262
# std           1.188241
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# 90%           5.000000
# 95%           5.000000
# 99%           6.000000
# max          94.000000
# Name: BedroomsTotal, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['BathroomsTotalInteger'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('BathroomsTotalInteger Histogram (log scale)')

ax[1] = listing['BathroomsTotalInteger'].plot(kind="box", vert=False)
ax[1].set_title('BathroomsTotalInteger Boxplot')

plt.tight_layout()
plt.show()
listing['BathroomsTotalInteger'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    566616.000000
# mean          2.628851
# std           3.193521
# min           0.000000
# 25%           2.000000
# 50%           2.000000
# 75%           3.000000
# 90%           4.000000
# 95%           5.000000
# 99%           7.000000
# max        2208.000000
# Name: BathroomsTotalInteger, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['DaysOnMarket'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('DaysOnMarket Histogram (log scale)')

ax[1] = listing['DaysOnMarket'].plot(kind="box", vert=False)
ax[1].set_title('DaysOnMarket Boxplot')

plt.tight_layout()
plt.show()
listing['DaysOnMarket'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    566673.000000
# mean         19.107844
# std          26.315334
# min         -58.000000
# 25%           5.000000
# 50%          11.000000
# 75%          22.000000
# 90%          42.000000
# 95%          69.000000
# 99%         137.000000
# max         731.000000
# Name: DaysOnMarket, dtype: float64

# %%
fig, ax = plt.subplots(2, 1, figsize=(8,8))
ax[0].hist(listing['YearBuilt'], bins=50)
ax[0].set_yscale('log')
ax[0].set_title('YearBuilt Histogram (log scale)')

ax[1] = listing['YearBuilt'].plot(kind="box", vert=False)
ax[1].set_title('YearBuilt Boxplot')

plt.tight_layout()
plt.show()
listing['YearBuilt'].describe(percentiles=[0.25,0.5,0.75,0.9,0.95,0.99])
# Out:
# count    565691.000000
# mean       1979.654287
# std          27.009042
# min        1776.000000
# 25%        1961.000000
# 50%        1980.000000
# 75%        2001.000000
# 90%        2018.000000
# 95%        2023.000000
# 99%        2025.000000
# max        2028.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# # Reminder
# - Change specified dtpyes
# - Drop columns with '.1'
# - Drop metadata columns
# - Drop 99th percentile
# - Drop missing columns
